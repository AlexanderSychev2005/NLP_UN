# %%
import pandas as pd

# %%
dataset = pd.read_csv("monitoring_results_v2.csv")

# %%
dataset.head(5)
# Out:
#          Date            Time Source  \
# 0  2026-02-17      Day: 13:59    BBC
# 1  2026-02-17      Day: 13:59   CNBC
# 2  2026-02-18  Morning: 08:10    BBC
# 3  2026-02-18  Morning: 08:10   CNBC
# 4  2026-02-18      Day: 17:34    BBC
#
#                                             Raw_Text  \
# 0  US civil rights leader Jesse Jackson dies aged...
# 1  India discussing age-based restrictions with s...
# 2  I would scream in my sleep: Women from Syria's...
# 3  Businesses scramble to reach China's growing e...
# 4  'Difficult' Russia-Ukraine peace talks end wit...
#
#                                    Top_5_Terms     Frequencies
# 0       winter, olympics, curling, cup, leader  10, 8, 6, 5, 4
# 1        investors, stocks, india, firms, data   4, 3, 2, 2, 2
# 2  winter, athletes, jesse, interview, curling  10, 5, 4, 4, 4
# 3               stock, big, stocks, palo, alto   4, 4, 4, 3, 3
# 4   olympics, president, winter, curling, gold   8, 7, 7, 6, 6
